# %% [markdown]
# ## Scales in Pandas

# %% [markdown]
# categorical_var = df[columnName].astype("category"): return the same series with the columnName as category datatype rather than object (categorical variable)
#
# df[ df[columnName] > val_in_columnName]: return all values have alphbatical value more than val_in_columnName
#
#
#
#
# my_categories= pd.CategoricalDtype( categories= [listOfCategories], ordered= True )
# ordinal_var = df[columnName].astype(my_categories)
# that returned the same series with columnName as ordered categories (ordinal varibale) as order as listOfCategories
#
#
# # after order categorizing of a column:
# df[ df[columnName] > val_in_listOfCategories ] : that will return the df where columnName category is better than val_in_listOfCategories
#
#
#
#
#
#
#
# pd.cut(df[columnName], n): it takes a pandas series and an int n, it divide the range (max-min) of the values of columnName to n equels interevals, then it return a series where each value replaced with its intereval.
